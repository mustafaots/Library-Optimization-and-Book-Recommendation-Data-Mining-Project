# %%
1. Borrowing Behavior by Category
Borrowing duration varies significantly across categories, with some categories (likely academic or reference) being borrowed for longer periods.

Certain categories have higher average borrow counts, indicating higher demand or popularity.

2. Popularity vs. Borrowing Duration
There is no strong linear relationship between borrowing duration and borrow count (popularity). Some books are borrowed frequently but for short periods, while others are borrowed less often but kept longer.

3. Copy Count vs. Borrow Count
Books with more copies in the catalogue tend to have higher borrow counts, but the relationship is not perfectly linear—some books with few copies are still highly borrowed, indicating high demand relative to availability.

4. Inventory Status
The majority of books are available for external lending.

A smaller portion is reserved for on-site consultation.

A very small percentage is marked as lost.

5. Distribution of Borrowing Duration
Most borrowings are short-term (under 50 days), with a sharp decline in frequency as duration increases.

Long-term borrowings (over 150 days) are rare.

6. Book Copy Distribution
Most books in the catalogue have few copies (1–2 copies per title).

A small number of titles have many copies (up to 150+), likely indicating high-demand or required reading materials.

7. Subject Focus (from French titles)
The collection has a strong focus on mathematics and academic subjects (algebra, analysis, probability, real functions, etc.), suggesting this may be an academic or specialized library.

Recommendations Based on Insights:
Increase copies of highly borrowed titles with low copy counts to meet demand.

Review long-term borrowings to ensure timely returns and availability.

Consider digital or on-site access for high-demand reference materials to reduce wait times.

Monitor “lost” books and consider replacement or digital alternatives.

Would you like me to visualize any of these insights in a summary dashboard format?

give me result in order to put it in my file key insight
📊 Key Insights for Library Data Analysis Report
1. Borrowing Patterns by Category
Borrowing duration varies across categories, with academic/reference materials typically borrowed longer.

Certain categories show higher average borrow counts, indicating greater reader interest or curricular relevance.

2. Popularity vs. Loan Duration
No strong correlation exists between how often a book is borrowed and how long it is kept.

Some high-demand titles are borrowed frequently but for short periods, while niche titles are borrowed less often but retained longer.

3. Copy Availability vs. Usage
Generally, more copies lead to more borrows, but some titles with few copies are highly sought after.

Suggests potential under-stocking of certain high-demand books.

4. Inventory Status Overview
Majority of books: Available for external lending

Smaller portion: Reserved for on-site use only

Minimal losses: Very few books marked as lost

5. Loan Duration Distribution
Most loans are short-term (under 50 days)

Long-term loans (>150 days) are uncommon

Implies good reader adherence to standard loan periods

6. Catalogue Copy Distribution
Most titles have 1–2 copies

A limited number of titles have high copy counts (up to 150+), indicating prioritized or high-demand materials

7. Collection Specialty
Strong focus on mathematics and academic subjects (algebra, analysis, probability)

Suggests an academic or research-oriented library

✅ Recommendations:
Increase copies of high-borrow, low-copy titles

Review long-loan items for potential recalls or policy adjustments

Consider digital access for high-demand reference works

Develop replacement strategy for lost/damaged high-use items
